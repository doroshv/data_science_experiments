# %% [markdown]
# # Crowdflower Search Results Relevance
#
# Educational take on one of the more popular past [kaggle challenges](https://www.kaggle.com/c/crowdflower-search-relevance/data) challenges from 2015. In the second notebook (crowdflower_llm_brute) I solve this task using LLMs, just for fun, but here I try to stay sensible and get reasonably high score quickly ("good enough" for educational purposes using mostly sklearn).

# %%
import pandas as pd
df = pd.read_csv('train.csv')
print(df.describe())
print(df.isna().sum())
df.sample(3)
# Out:
#                  id  median_relevance  relevance_variance
# count  10158.000000      10158.000000        10158.000000
# mean   16353.103071          3.309805            0.377863
# std     9447.106683          0.980666            0.389707
# min        1.000000          1.000000            0.000000
# 25%     8078.750000          3.000000            0.000000
# 50%    16349.500000          4.000000            0.471000
# 75%    24570.750000          4.000000            0.471000
# max    32668.000000          4.000000            1.470000
# id                        0
# query                     0
# product_title             0
# product_description    2444
# median_relevance          0
# relevance_variance        0
# dtype: int64
#          id                     query  \
# 8447  27179  vanilla scented perfumes
# 4296  13898  polar heart rate monitor
# 2091   6712            wreck it ralph
#
#                                           product_title  \
# 8447  Aquolina Pink Sugar Women's 3.4-ounce Eau de T...
# 4296      Polar V800 GPS & Heart Rate Monitor Watch Set
# 2091  Wreck-It Ralph (Blu-ray/DVD, 2013, 2-Disc Set)...
#
#                                     product_description  median_relevance  \
# 8447  Introduced by the design house of Aquolina in ...                 2
# 4296                                                NaN                 4
# 2091                                                NaN                 3
#
#       relevance_variance
# 8447               1.095
# 4296               0.000
# 2091               0.943

# %%
df_test = pd.read_csv('test.csv')
print(df_test.describe())
print(df_test.isna().sum())
df_test.sample(3)
# Out:
#                  id
# count  22513.000000
# mean   16328.282992
# std     9424.576451
# min        3.000000
# 25%     8201.000000
# 50%    16329.000000
# 75%    24464.000000
# max    32671.000000
# id                        0
# query                     0
# product_title             0
# product_description    5427
# dtype: int64
#           id               query  \
# 20502  29757         wall clocks
# 13443  19510     full tang knife
# 17392  25224  decorative pillows
#
#                                            product_title  \
# 20502                    Lorell Radio Control Wall Clock
# 13443  Whetstone Black Forest Full Tang Cherry Pakkaw...
# 17392           Cotton Tale Girly Pillow Pack (Set of 3)
#
#                                      product_description
# 20502  Lorell Radio Control Wall Clock - Digital - Qu...
# 13443  Whetstone Cutlery's Black Forest knife with sh...
# 17392                                                NaN

# %% [markdown]
# One can note that description has quite a few missing values, so it makes sense to concatenate title and description as a first step. Plus title/description fields contain html tags which are better to be stripped, so run some preprocessing on both sets:

# %%
from bs4 import BeautifulSoup
import re

def clean_text(dirty_text):
    soup = BeautifulSoup(str(dirty_text), "html.parser")
    text_only = soup.get_text()
    # Use regex to remove special characters and keep only alphanumeric characters and spaces
    clean_text = re.sub(r'[^A-Za-z0-9\s]+', '', text_only)
    # Optional: Normalize spaces (remove extra spaces)
    clean_text = re.sub(r'\s+', ' ', clean_text).strip()
    return clean_text.lower()

df['product_title'] = df['product_title'].apply(clean_text)
df['product_description'] = df['product_description'].apply(clean_text)
df_test['product_title'] = df_test['product_title'].apply(clean_text)
df_test['product_description'] = df_test['product_description'].apply(clean_text)
# df['matching'] = df['query'].str.cat(df['product_title'].str.cat(df['product_description'], sep=' ', na_rep=''))
# df_test['matching'] = df_test['query'].str.cat(df_test['product_title'].str.cat(df_test['product_description'], sep=' ', na_rep=''))
df['matching'] = df['query'].str.cat(df['product_title'])
df_test['matching'] = df_test['query'].str.cat(df_test['product_title'])
# Out:
# /var/folders/l9/yhh7ptgx6dqb97khkd08bkmw0000gn/T/ipykernel_13730/411608331.py:5: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(str(dirty_text), "html.parser")
# /var/folders/l9/yhh7ptgx6dqb97khkd08bkmw0000gn/T/ipykernel_13730/411608331.py:5: MarkupResemblesLocatorWarning: The input looks more like a URL than markup. You may want to use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   soup = BeautifulSoup(str(dirty_text), "html.parser")

# %% [markdown]
# Now we need some way to measure similarity between various queries and results:

# %%
from sklearn.feature_extraction.text import TfidfVectorizer 
from sklearn.metrics.pairwise import cosine_similarity
# get a nice mix of models for ensemble
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.decomposition import TruncatedSVD
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import cohen_kappa_score, make_scorer

# fit vectorizer using full vocabulary (concatenate train and test query + title + description
tfid = TfidfVectorizer(min_df=3,  max_features=None,
                       strip_accents='unicode', analyzer='word',token_pattern=r'\w{1,}',
                       ngram_range=(1, 5), use_idf=True,smooth_idf=True,sublinear_tf=True,
                       stop_words = 'english').fit(pd.concat([df['matching'],df_test['matching']]))

# %% [markdown]
# Now we can get actual features and labels and train the model. Use kappa scorer as per competition definition, and start with C-Support Vector Classification as model first. Prior to fit, reduce dimensionality with TruncatedSVD and apply standard scaling as part of the pipeline

# %%
x_train = tfid.transform(df['matching'][df['relevance_variance']==0].to_numpy())
x_test = tfid.transform(df_test['matching'].to_numpy())
y = df['median_relevance'][df['relevance_variance']==0].to_numpy()

# %%
svm = Pipeline([('svd', TruncatedSVD()),
    						 ('scaler', StandardScaler()),
                    	     ('svm', SVC())])
qwk_scorer = make_scorer(cohen_kappa_score, weights='quadratic', greater_is_better=True)
param_grid = {'svd__n_components' : [420,430,440],
                  'svm__C': [32,34,36]}
model = GridSearchCV(estimator = svm, param_grid=param_grid, scoring=qwk_scorer,
                                     verbose=0, n_jobs=-1, refit=True, cv=4)

# %%
model.fit(x_train, y)
print(f"best score: {model.best_score_}")
# Out:
# Fitting 4 folds for each of 9 candidates, totalling 36 fits
# best score: 0.5683069851949141

# %%
model.best_params_
# Out:
# {'svd__n_components': 430, 'svm__C': 34}

# %% [markdown]
# Now can repeat excercise with a different model, for instance, KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = Pipeline([('svd', TruncatedSVD()),
    						 ('scaler', StandardScaler()),
                    	     ('knn', KNeighborsClassifier())])

param_grid1 = {'svd__n_components' : [420,430,440],
                  'knn__n_neighbors': [3,5,10]}
model1 = GridSearchCV(estimator = knn, param_grid=param_grid1, scoring=qwk_scorer,
                                     verbose=0, n_jobs=-1, refit=True, cv=4)

# %%
model1.fit(x_train, y)
print(f"best score: {model1.best_score_}")
# Out:
# Fitting 4 folds for each of 9 candidates, totalling 36 fits
# best score: 0.5262470131103949

# %%
model1.best_params_
# Out:
# {'knn__n_neighbors': 3, 'svd__n_components': 430}

# %% [markdown]
# And simple logistic regression:

# %%
from sklearn.linear_model import LogisticRegression

lr = Pipeline([('svd', TruncatedSVD()),
    						 ('scaler', StandardScaler()),
                    	     ('lr', LogisticRegression(solver='saga',max_iter=10000))])

param_grid2 = {'svd__n_components' : [410,420,430],
                  'lr__C': [20,30,50]}
model2 = GridSearchCV(estimator = lr, param_grid=param_grid2, scoring=qwk_scorer,
                                     verbose=0, n_jobs=-1, refit=True, cv=4)

# %%
model2.fit(x_train, y)
print(f"best score: {model2.best_score_}")
# Out:
# Fitting 4 folds for each of 9 candidates, totalling 36 fits
# best score: 0.4737610482925336
# [CV 3/4; 1/9] START lr__C=20, svd__n_components=410.............................
# [CV 3/4; 1/9] END lr__C=20, svd__n_components=410;, score=0.469 total time= 1.7min
# [CV 1/4; 5/9] START lr__C=30, svd__n_components=420.............................
# [CV 1/4; 5/9] END lr__C=30, svd__n_components=420;, score=0.471 total time= 1.4min
# [CV 2/4; 7/9] START lr__C=50, svd__n_components=410.............................
# [CV 2/4; 7/9] END lr__C=50, svd__n_components=410;, score=0.486 total time= 1.7min
# [CV 2/4; 3/9] START lr__C=20, svd__n_components=430.............................
# [CV 2/4; 3/9] END lr__C=20, svd__n_components=430;, score=0.472 total time= 1.7min
# [CV 2/4; 5/9] START lr__C=30, svd__n_components=420.............................
# [CV 2/4; 5/9] END lr__C=30, svd__n_components=420;, score=0.511 total time= 1.5min
# [CV 1/4; 8/9] START lr__C=50, svd__n_components=420.............................
# [CV 1/4; 8/9] END lr__C=50, svd__n_components=420;, score=0.441 total time= 1.6min
# [CV 1/4; 2/9] START lr__C=20, svd__n_components=420.............................
# [CV 1/4; 2/9] END lr__C=20, svd__n_components=420;, score=0.460 total time= 2.0min
# [CV 4/4; 5/9] START lr__C=30, svd__n_components=420.............................
# [CV 4/4; 5/9] END lr__C=30, svd__n_components=420;, score=0.424 total time= 1.3min
# [CV 2/4; 8/9] START lr__C=50, svd__n_components=420.............................
# [CV 2/4; 8/9] END lr__C=50, svd__n_components=420;, score=0.415 total time= 1.6min
# [CV 3/4; 2/9] START lr__C=20, svd__n_components=420.............................
# [CV 3/4; 2/9] END lr__C=20, svd__n_components=420;, score=0.477 total time= 1.8min
# [CV 3/4; 5/9] START lr__C=30, svd__n_components=420.............................
# [CV 3/4; 5/9] END lr__C=30, svd__n_components=420;, score=0.488 total time= 1.5min
# [CV 3/4; 7/9] START lr__C=50, svd__n_components=410.............................
# [CV 3/4; 7/9] END lr__C=50, svd__n_components=410;, score=0.467 total time= 1.9min
# [CV 2/4; 1/9] START lr__C=20, svd__n_components=410.............................
# [CV 2/4; 1/9] END lr__C=20, svd__n_components=410;, score=0.494 total time= 1.5min
# [CV 3/4; 4/9] START lr__C=30, svd__n_components=410.............................
# [CV 3/4; 4/9] END lr__C=30, svd__n_components=410;, score=0.467 total time= 1.4min
# [CV 3/4; 6/9] START lr__C=30, svd__n_components=430.............................
# [CV 3/4; 6/9] END lr__C=30, svd__n_components=430;, score=0.501 total time= 1.4min
# [CV 3/4; 8/9] START lr__C=50, svd__n_components=420.............................
# [CV 3/4; 8/9] END lr__C=50, svd__n_components=420;, score=0.504 total time= 1.3min
# [CV 4/4; 2/9] START lr__C=20, svd__n_components=420.............................
# [CV 4/4; 2/9] END lr__C=20, svd__n_components=420;, score=0.424 total time= 1.5min
# [CV 4/4; 3/9] START lr__C=20, svd__n_components=430.............................
# [CV 4/4; 3/9] END lr__C=20, svd__n_components=430;, score=0.428 total time= 1.4min
# [CV 1/4; 6/9] START lr__C=30, svd__n_components=430.............................
# [CV 1/4; 6/9] END lr__C=30, svd__n_components=430;, score=0.444 total time= 1.6min
# [CV 4/4; 8/9] START lr__C=50, svd__n_components=420.............................
# [CV 4/4; 8/9] END lr__C=50, svd__n_components=420;, score=0.500 total time= 1.3min
# [CV 1/4; 3/9] START lr__C=20, svd__n_components=430.............................
# [CV 1/4; 3/9] END lr__C=20, svd__n_components=430;, score=0.459 total time= 1.5min
# [CV 1/4; 4/9] START lr__C=30, svd__n_components=410.............................
# [CV 1/4; 4/9] END lr__C=30, svd__n_components=410;, score=0.430 total time= 1.5min
# [CV 1/4; 7/9] START lr__C=50, svd__n_components=410.............................
# [CV 1/4; 7/9] END lr__C=50, svd__n_components=410;, score=0.420 total time= 1.6min
# [CV 4/4; 9/9] START lr__C=50, svd__n_components=430.............................
# [CV 4/4; 9/9] END lr__C=50, svd__n_components=430;, score=0.434 total time= 1.3min
# [CV 2/4; 2/9] START lr__C=20, svd__n_components=420.............................
# [CV 2/4; 2/9] END lr__C=20, svd__n_components=420;, score=0.457 total time= 1.6min
# [CV 4/4; 4/9] START lr__C=30, svd__n_components=410.............................
# [CV 4/4; 4/9] END lr__C=30, svd__n_components=410;, score=0.439 total time= 1.2min
# [CV 2/4; 6/9] START lr__C=30, svd__n_components=430.............................
# [CV 2/4; 6/9] END lr__C=30, svd__n_components=430;, score=0.452 total time= 1.6min
# [CV 1/4; 9/9] START lr__C=50, svd__n_components=430.............................
# [CV 1/4; 9/9] END lr__C=50, svd__n_components=430;, score=0.463 total time= 1.5min
# [CV 1/4; 1/9] START lr__C=20, svd__n_components=410.............................
# [CV 1/4; 1/9] END lr__C=20, svd__n_components=410;, score=0.455 total time= 1.5min
# [CV 2/4; 4/9] START lr__C=30, svd__n_components=410.............................
# [CV 2/4; 4/9] END lr__C=30, svd__n_components=410;, score=0.477 total time= 1.4min
# [CV 4/4; 6/9] START lr__C=30, svd__n_components=430.............................
# [CV 4/4; 6/9] END lr__C=30, svd__n_components=430;, score=0.424 total time= 1.6min
# [CV 2/4; 9/9] START lr__C=50, svd__n_components=430.............................
# [CV 2/4; 9/9] END lr__C=50, svd__n_components=430;, score=0.455 total time= 1.5min
# [CV 4/4; 1/9] START lr__C=20, svd__n_components=410.............................
# [CV 4/4; 1/9] END lr__C=20, svd__n_components=410;, score=0.398 total time= 1.4min
# [CV 3/4; 3/9] START lr__C=20, svd__n_components=430.............................
# [CV 3/4; 3/9] END lr__C=20, svd__n_components=430;, score=0.507 total time= 1.9min
# [CV 4/4; 7/9] START lr__C=50, svd__n_components=410.............................
# [CV 4/4; 7/9] END lr__C=50, svd__n_components=410;, score=0.435 total time= 1.3min
# [CV 3/4; 9/9] START lr__C=50, svd__n_components=430.............................
# [CV 3/4; 9/9] END lr__C=50, svd__n_components=430;, score=0.494 total time= 1.5min

# %%
model2.best_params_
# Out:
# {'lr__C': 30, 'svd__n_components': 420}
# [CV 4/4; 2/9] START knn__n_neighbors=3, svd__n_components=430...................
# [CV 4/4; 2/9] END knn__n_neighbors=3, svd__n_components=430;, score=0.436 total time=  15.9s
# [CV 1/4; 5/9] START knn__n_neighbors=5, svd__n_components=430...................
# [CV 1/4; 5/9] END knn__n_neighbors=5, svd__n_components=430;, score=0.434 total time=  13.7s
# [CV 3/4; 7/9] START knn__n_neighbors=10, svd__n_components=420..................
# [CV 3/4; 7/9] END knn__n_neighbors=10, svd__n_components=420;, score=0.324 total time=  13.9s
# [CV 4/4; 2/9] START lr__C=10, svd__n_components=430.............................
# [CV 4/4; 2/9] END lr__C=10, svd__n_components=430;, score=0.432 total time=  16.7s
# [CV 1/4; 5/9] START lr__C=20, svd__n_components=430.............................
# [CV 1/4; 5/9] END lr__C=20, svd__n_components=430;, score=0.435 total time=  17.2s
# [CV 1/4; 7/9] START lr__C=30, svd__n_components=420.............................
# [CV 1/4; 7/9] END lr__C=30, svd__n_components=420;, score=0.457 total time=  16.6s
# [CV 3/4; 8/9] START lr__C=30, svd__n_components=430.............................
# [CV 3/4; 8/9] END lr__C=30, svd__n_components=430;, score=0.506 total time=  10.3s
# [CV 2/4; 1/9] START lr__C=10, svd__n_components=420.............................
# [CV 2/4; 1/9] END lr__C=10, svd__n_components=420;, score=nan total time=  15.0s
# [CV 4/4; 3/9] START lr__C=10, svd__n_components=440.............................
# [CV 4/4; 3/9] END lr__C=10, svd__n_components=440;, score=nan total time=  13.8s
# [CV 1/4; 6/9] START lr__C=20, svd__n_components=440.............................
# [CV 1/4; 6/9] END lr__C=20, svd__n_components=440;, score=nan total time=  14.2s
# [CV 4/4; 8/9] START lr__C=30, svd__n_components=430.............................
# [CV 4/4; 8/9] END lr__C=30, svd__n_components=430;, score=nan total time=  10.0s
# [CV 2/4; 1/9] START lr__C=10, svd__n_components=420.............................
# [CV 2/4; 1/9] END lr__C=10, svd__n_components=420;, score=0.522 total time=  36.7s
# [CV 3/4; 3/9] START lr__C=10, svd__n_components=440.............................
# [CV 3/4; 3/9] END lr__C=10, svd__n_components=440;, score=0.523 total time=  37.2s
# [CV 2/4; 6/9] START lr__C=20, svd__n_components=440.............................
# [CV 2/4; 6/9] END lr__C=20, svd__n_components=440;, score=0.486 total time=  38.1s
# [CV 3/4; 9/9] START lr__C=30, svd__n_components=440.............................
# [CV 3/4; 9/9] END lr__C=30, svd__n_components=440;, score=0.469 total time=  27.9s
# [CV 2/4; 1/9] START lr__C=10, svd__n_components=420.............................
# [CV 2/4; 1/9] END lr__C=10, svd__n_components=420;, score=0.456 total time= 1.4min
# [CV 1/4; 4/9] START lr__C=20, svd__n_components=420.............................
# [CV 1/4; 4/9] END lr__C=20, svd__n_components=420;, score=0.464 total time= 1.4min
# [CV 4/4; 6/9] START lr__C=20, svd__n_components=440.............................
# [CV 4/4; 6/9] END lr__C=20, svd__n_components=440;, score=0.453 total time= 1.4min
# [CV 4/4; 8/9] START lr__C=30, svd__n_components=430.............................
# [CV 4/4; 8/9] END lr__C=30, svd__n_components=430;, score=0.405 total time= 1.4min
# [CV 2/4; 2/9] START knn__n_neighbors=3, svd__n_components=430...................
# [CV 2/4; 2/9] END knn__n_neighbors=3, svd__n_components=430;, score=0.650 total time=  15.1s
# [CV 3/4; 4/9] START knn__n_neighbors=5, svd__n_components=420...................
# [CV 3/4; 4/9] END knn__n_neighbors=5, svd__n_components=420;, score=0.438 total time=  13.1s
# [CV 2/4; 6/9] START knn__n_neighbors=5, svd__n_components=440...................
# [CV 2/4; 6/9] END knn__n_neighbors=5, svd__n_components=440;, score=0.513 total time=  15.2s
# [CV 1/4; 1/9] START lr__C=10, svd__n_components=420.............................
# [CV 1/4; 1/9] END lr__C=10, svd__n_components=420;, score=0.447 total time=  14.4s
# [CV 3/4; 3/9] START lr__C=10, svd__n_components=440.............................
# [CV 3/4; 3/9] END lr__C=10, svd__n_components=440;, score=0.481 total time=  20.0s
# [CV 2/4; 7/9] START lr__C=30, svd__n_components=420.............................
# [CV 2/4; 7/9] END lr__C=30, svd__n_components=420;, score=0.475 total time=  17.7s
# [CV 4/4; 9/9] START lr__C=30, svd__n_components=440.............................
# [CV 4/4; 9/9] END lr__C=30, svd__n_components=440;, score=0.450 total time=   9.6s
# [CV 4/4; 1/9] START lr__C=10, svd__n_components=420.............................
# [CV 4/4; 1/9] END lr__C=10, svd__n_components=420;, score=nan total time=  15.7s
# [CV 1/4; 4/9] START lr__C=20, svd__n_components=420.............................
# [CV 1/4; 4/9] END lr__C=20, svd__n_components=420;, score=nan total time=  14.2s
# [CV 3/4; 6/9] START lr__C=20, svd__n_components=440.............................
# [CV 3/4; 6/9] END lr__C=20, svd__n_components=440;, score=nan total time=  14.6s
# [CV 1/4; 9/9] START lr__C=30, svd__n_components=440.............................
# [CV 1/4; 9/9] END lr__C=30, svd__n_components=440;, score=nan total time=   9.4s
# [CV 1/4; 3/9] START lr__C=10, svd__n_components=440.............................
# [CV 1/4; 3/9] END lr__C=10, svd__n_components=440;, score=0.429 total time=  39.3s
# [CV 3/4; 5/9] START lr__C=20, svd__n_components=430.............................
# [CV 3/4; 5/9] END lr__C=20, svd__n_components=430;, score=0.482 total time=  35.3s
# [CV 1/4; 7/9] START lr__C=30, svd__n_components=420.............................
# [CV 1/4; 7/9] END lr__C=30, svd__n_components=420;, score=0.463 total time=  37.1s
# [CV 2/4; 9/9] START lr__C=30, svd__n_components=440.............................
# [CV 2/4; 9/9] END lr__C=30, svd__n_components=440;, score=0.473 total time=  28.2s
# [CV 4/4; 1/9] START lr__C=10, svd__n_components=420.............................
# [CV 4/4; 1/9] END lr__C=10, svd__n_components=420;, score=0.426 total time= 1.3min
# [CV 4/4; 3/9] START lr__C=10, svd__n_components=440.............................
# [CV 4/4; 3/9] END lr__C=10, svd__n_components=440;, score=0.401 total time= 1.3min
# [CV 1/4; 6/9] START lr__C=20, svd__n_components=440.............................
# [CV 1/4; 6/9] END lr__C=20, svd__n_components=440;, score=0.454 total time= 1.6min
# [CV 1/4; 9/9] START lr__C=30, svd__n_components=440.............................
# [CV 1/4; 9/9] END lr__C=30, svd__n_components=440;, score=0.443 total time= 1.6min
# [CV 1/4; 1/9] START knn__n_neighbors=3, svd__n_components=420...................
# [CV 1/4; 1/9] END knn__n_neighbors=3, svd__n_components=420;, score=0.485 total time=  13.8s
# [CV 3/4; 3/9] START knn__n_neighbors=3, svd__n_components=440...................
# [CV 3/4; 3/9] END knn__n_neighbors=3, svd__n_components=440;, score=0.513 total time=  14.5s
# [CV 4/4; 6/9] START knn__n_neighbors=5, svd__n_components=440...................
# [CV 4/4; 6/9] END knn__n_neighbors=5, svd__n_components=440;, score=0.414 total time=  14.0s
# [CV 2/4; 9/9] START knn__n_neighbors=10, svd__n_components=440..................
# [CV 2/4; 9/9] END knn__n_neighbors=10, svd__n_components=440;, score=0.373 total time=   7.9s
# [CV 1/4; 2/9] START lr__C=10, svd__n_components=430.............................
# [CV 1/4; 2/9] END lr__C=10, svd__n_components=430;, score=0.449 total time=  15.5s
# [CV 2/4; 4/9] START lr__C=20, svd__n_components=420.............................
# [CV 2/4; 4/9] END lr__C=20, svd__n_components=420;, score=0.444 total time=  17.8s
# [CV 3/4; 6/9] START lr__C=20, svd__n_components=440.............................
# [CV 3/4; 6/9] END lr__C=20, svd__n_components=440;, score=0.520 total time=  17.8s
# [CV 2/4; 9/9] START lr__C=30, svd__n_components=440.............................
# [CV 2/4; 9/9] END lr__C=30, svd__n_components=440;, score=0.455 total time=  10.3s
# [CV 1/4; 3/9] START lr__C=10, svd__n_components=440.............................
# [CV 1/4; 3/9] END lr__C=10, svd__n_components=440;, score=nan total time=  17.3s
# [CV 4/4; 4/9] START lr__C=20, svd__n_components=420.............................
# [CV 4/4; 4/9] END lr__C=20, svd__n_components=420;, score=nan total time=  15.6s
# [CV 2/4; 7/9] START lr__C=30, svd__n_components=420.............................
# [CV 2/4; 7/9] END lr__C=30, svd__n_components=420;, score=nan total time=  13.8s
# [CV 4/4; 9/9] START lr__C=30, svd__n_components=440.............................
# [CV 4/4; 9/9] END lr__C=30, svd__n_components=440;, score=nan total time=   8.0s
# [CV 2/4; 3/9] START lr__C=10, svd__n_components=440.............................
# [CV 2/4; 3/9] END lr__C=10, svd__n_components=440;, score=0.509 total time=  39.7s
# [CV 4/4; 5/9] START lr__C=20, svd__n_components=430.............................
# [CV 4/4; 5/9] END lr__C=20, svd__n_components=430;, score=0.414 total time=  36.2s
# [CV 1/4; 8/9] START lr__C=30, svd__n_components=430.............................
# [CV 1/4; 8/9] END lr__C=30, svd__n_components=430;, score=0.428 total time=  37.0s
# [CV 1/4; 1/9] START lr__C=10, svd__n_components=420.............................
# [CV 1/4; 1/9] END lr__C=10, svd__n_components=420;, score=0.444 total time= 1.3min
# [CV 3/4; 3/9] START lr__C=10, svd__n_components=440.............................
# [CV 3/4; 3/9] END lr__C=10, svd__n_components=440;, score=0.480 total time= 1.4min
# [CV 2/4; 6/9] START lr__C=20, svd__n_components=440.............................
# [CV 2/4; 6/9] END lr__C=20, svd__n_components=440;, score=0.452 total time= 1.6min
# [CV 2/4; 9/9] START lr__C=30, svd__n_components=440.............................
# [CV 2/4; 9/9] END lr__C=30, svd__n_components=440;, score=0.454 total time= 1.5min
# [CV 3/4; 1/9] START knn__n_neighbors=3, svd__n_components=420...................
# [CV 3/4; 1/9] END knn__n_neighbors=3, svd__n_components=420;, score=0.501 total time=  14.0s
# [CV 2/4; 4/9] START knn__n_neighbors=5, svd__n_components=420...................
# [CV 2/4; 4/9] END knn__n_neighbors=5, svd__n_components=420;, score=0.533 total time=  14.3s
# [CV 3/4; 6/9] START knn__n_neighbors=5, svd__n_components=440...................
# [CV 3/4; 6/9] END knn__n_neighbors=5, svd__n_components=440;, score=0.439 total time=  15.0s
# [CV 4/4; 9/9] START knn__n_neighbors=10, svd__n_components=440..................
# [CV 4/4; 9/9] END knn__n_neighbors=10, svd__n_components=440;, score=0.380 total time=   7.6s
# [CV 2/4; 3/9] START lr__C=10, svd__n_components=440.............................
# [CV 2/4; 3/9] END lr__C=10, svd__n_components=440;, score=0.462 total time=  17.2s
# [CV 4/4; 5/9] START lr__C=20, svd__n_components=430.............................
# [CV 4/4; 5/9] END lr__C=20, svd__n_components=430;, score=0.435 total time=  19.8s
# [CV 4/4; 7/9] START lr__C=30, svd__n_components=420.............................
# [CV 4/4; 7/9] END lr__C=30, svd__n_components=420;, score=0.397 total time=  18.0s
# [CV 4/4; 2/9] START lr__C=10, svd__n_components=430.............................
# [CV 4/4; 2/9] END lr__C=10, svd__n_components=430;, score=nan total time=  16.0s
# [CV 3/4; 4/9] START lr__C=20, svd__n_components=420.............................
# [CV 3/4; 4/9] END lr__C=20, svd__n_components=420;, score=nan total time=  15.7s
# [CV 1/4; 7/9] START lr__C=30, svd__n_components=420.............................
# [CV 1/4; 7/9] END lr__C=30, svd__n_components=420;, score=nan total time=  14.2s
# [CV 3/4; 9/9] START lr__C=30, svd__n_components=440.............................
# [CV 3/4; 9/9] END lr__C=30, svd__n_components=440;, score=nan total time=   8.3s
# [CV 4/4; 1/9] START lr__C=10, svd__n_components=420.............................
# [CV 4/4; 1/9] END lr__C=10, svd__n_components=420;, score=0.398 total time=  37.4s
# [CV 4/4; 3/9] START lr__C=10, svd__n_components=440.............................
# [CV 4/4; 3/9] END lr__C=10, svd__n_components=440;, score=0.410 total time=  38.6s
# [CV 2/4; 8/9] START lr__C=30, svd__n_components=430.............................
# [CV 2/4; 8/9] END lr__C=30, svd__n_components=430;, score=0.443 total time=  37.1s
# [CV 4/4; 2/9] START lr__C=10, svd__n_components=430.............................
# [CV 4/4; 2/9] END lr__C=10, svd__n_components=430;, score=0.449 total time= 1.4min
# [CV 1/4; 5/9] START lr__C=20, svd__n_components=430.............................
# [CV 1/4; 5/9] END lr__C=20, svd__n_components=430;, score=0.452 total time= 1.4min
# [CV 2/4; 7/9] START lr__C=30, svd__n_components=420.............................
# [CV 2/4; 7/9] END lr__C=30, svd__n_components=420;, score=0.472 total time= 1.6min
# [CV 4/4; 9/9] START lr__C=30, svd__n_components=440.............................
# [CV 4/4; 9/9] END lr__C=30, svd__n_components=440;, score=0.395 total time= 1.4min
# [CV 3/4; 2/9] START knn__n_neighbors=3, svd__n_components=430...................
# [CV 3/4; 2/9] END knn__n_neighbors=3, svd__n_components=430;, score=0.524 total time=  16.1s
# [CV 2/4; 5/9] START knn__n_neighbors=5, svd__n_components=430...................
# [CV 2/4; 5/9] END knn__n_neighbors=5, svd__n_components=430;, score=0.528 total time=  15.2s
# [CV 1/4; 8/9] START knn__n_neighbors=10, svd__n_components=430..................
# [CV 1/4; 8/9] END knn__n_neighbors=10, svd__n_components=430;, score=0.247 total time=  13.7s
# [CV 4/4; 1/9] START lr__C=10, svd__n_components=420.............................
# [CV 4/4; 1/9] END lr__C=10, svd__n_components=420;, score=0.450 total time=  14.9s
# [CV 1/4; 4/9] START lr__C=20, svd__n_components=420.............................
# [CV 1/4; 4/9] END lr__C=20, svd__n_components=420;, score=0.422 total time=  18.1s
# [CV 1/4; 6/9] START lr__C=20, svd__n_components=440.............................
# [CV 1/4; 6/9] END lr__C=20, svd__n_components=440;, score=0.449 total time=  17.8s
# [CV 4/4; 8/9] START lr__C=30, svd__n_components=430.............................
# [CV 4/4; 8/9] END lr__C=30, svd__n_components=430;, score=0.402 total time=  10.0s
# [CV 2/4; 2/9] START lr__C=10, svd__n_components=430.............................
# [CV 2/4; 2/9] END lr__C=10, svd__n_components=430;, score=nan total time=  17.6s
# [CV 4/4; 5/9] START lr__C=20, svd__n_components=430.............................
# [CV 4/4; 5/9] END lr__C=20, svd__n_components=430;, score=nan total time=  16.1s
# [CV 3/4; 7/9] START lr__C=30, svd__n_components=420.............................
# [CV 3/4; 7/9] END lr__C=30, svd__n_components=420;, score=nan total time=  14.3s
# [CV 1/4; 1/9] START lr__C=10, svd__n_components=420.............................
# [CV 1/4; 1/9] END lr__C=10, svd__n_components=420;, score=0.418 total time=  37.7s
# [CV 1/4; 4/9] START lr__C=20, svd__n_components=420.............................
# [CV 1/4; 4/9] END lr__C=20, svd__n_components=420;, score=0.442 total time=  35.5s
# [CV 1/4; 6/9] START lr__C=20, svd__n_components=440.............................
# [CV 1/4; 6/9] END lr__C=20, svd__n_components=440;, score=0.421 total time=  38.4s
# [CV 1/4; 9/9] START lr__C=30, svd__n_components=440.............................
# [CV 1/4; 9/9] END lr__C=30, svd__n_components=440;, score=0.444 total time=  28.3s
# [CV 3/4; 2/9] START lr__C=10, svd__n_components=430.............................
# [CV 3/4; 2/9] END lr__C=10, svd__n_components=430;, score=0.504 total time= 1.4min
# [CV 2/4; 4/9] START lr__C=20, svd__n_components=420.............................
# [CV 2/4; 4/9] END lr__C=20, svd__n_components=420;, score=0.482 total time= 1.5min
# [CV 1/4; 7/9] START lr__C=30, svd__n_components=420.............................
# [CV 1/4; 7/9] END lr__C=30, svd__n_components=420;, score=0.441 total time= 1.5min
# [CV 3/4; 9/9] START lr__C=30, svd__n_components=440.............................
# [CV 3/4; 9/9] END lr__C=30, svd__n_components=440;, score=0.487 total time= 1.5min

# %%
from sklearn.linear_model import SGDClassifier

sgd = Pipeline([('svd', TruncatedSVD(n_components=400)),
    						 ('scaler', StandardScaler()),
                    	     ('sgd', SGDClassifier(loss='modified_huber',max_iter=10000,learning_rate='optimal',early_stopping=True,n_iter_no_change=5))])

param_grid3 = {
    "sgd__alpha": [1e-9,1e-8,1e-7,1e-6,1e-5],
    # "sgd__loss": ['hinge','squared_error','modified_huber'],
    # "sgd__penalty": ['l1','l2','elasticnet']
}

model3 = GridSearchCV(estimator = sgd, param_grid=param_grid3, scoring=qwk_scorer,
                                     verbose=0, n_jobs=-1, refit=True, cv=4)

# %%
model3.fit(x_train, y)
print(f"best score: {model3.best_score_}")
# Out:
# best score: 0.4114817749868326

# %% [markdown]
# Now we can try to take best of all classifiers and implement a voting classifier using full set, i.e. also values with high reported variance of the relevance.

# %%
x_train = tfid.transform(df['matching'].to_numpy())
x_test = tfid.transform(df_test['matching'].to_numpy())
y = df['median_relevance'].to_numpy()

# %%
from sklearn.ensemble import VotingClassifier, StackingClassifier
from sklearn.model_selection import cross_val_score

model.best_estimator_.set_params(svm__probability=False)
vcl = StackingClassifier(estimators=[
        ('svm', model.best_estimator_), 
        ('knn', model1.best_estimator_), 
        ('lr', model2.best_estimator_),
        ('sgd', model3.best_estimator_)],final_estimator=LogisticRegression(max_iter=10000),n_jobs=8)

vcl.fit(x_train,y,)
# Out:
# StackingClassifier(estimators=[('svm',
#                                 Pipeline(steps=[('svd',
#                                                  TruncatedSVD(n_components=430)),
#                                                 ('scaler', StandardScaler()),
#                                                 ('svm', SVC(C=36))])),
#                                ('knn',
#                                 Pipeline(steps=[('svd',
#                                                  TruncatedSVD(n_components=430)),
#                                                 ('scaler', StandardScaler()),
#                                                 ('knn',
#                                                  KNeighborsClassifier(n_neighbors=3))])),
#                                ('lr',
#                                 Pipeline(steps=[('svd',
#                                                  TruncatedSVD(n_components=420)),
#                                                 ('scaler', StandardScaler()),
#                                                 ('lr',
#                                                  LogisticRegression(C=30,
#                                                                     max_iter=10000,
#                                                                     solver='saga'))])),
#                                ('sgd',
#                                 Pipeline(steps=[('svd',
#                                                  TruncatedSVD(n_components=400)),
#                                                 ('scaler', StandardScaler()),
#                                                 ('sgd',
#                                                  SGDClassifier(alpha=1e-07,
#                                                                early_stopping=True,
#                                                                loss='modified_huber',
#                                                                max_iter=10000))]))],
#                    final_estimator=LogisticRegression(max_iter=10000),
#                    n_jobs=8)

# %%
ypred = vcl.predict(x_train)

# %% [markdown]
# And the $\kappa$ score for the full train set is:

# %%
cohen_kappa_score(y,ypred,weights='quadratic')
# Out:
# 0.779149935036425

# %% [markdown]
# Now verify with kaggle for the test set:

# %%
df_test['prediction'] = vcl.predict(x_test)

# %%
dfsub = pd.read_csv('sampleSubmission.csv')

# %%
df_test[['id','prediction']].to_csv('submission1.csv',index=False) # private score 0.54, public 0.51
